# %% [markdown]
# DATA CLEANING
#
# 1.check the number of columns
# 2.checking for missing values
# 3.checking for duplicate values

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# %%
#pd.set_option('display.max_columns',None) #not to truncate the columns

# %%
print(os.listdir())
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'Accidents_analysis.ipynb', 'Accidents_analysis.py', 'api_keys.py', 'LICENSE', 'output_data', 'README.md', 'Resources', '__pycache__']

# %%
#file to load--accident
accident_data_to_load = Path("./Resources/accident.csv")

#read accident, person, vehicle data file and store in to Pandas DataFrames

accident_data = pd.read_csv(accident_data_to_load)
accident_data
# Out:
#       index  accident_id  ST_CASE  VE_TOTAL  VE_FORMS  PEDS  PERSONS  COUNTY
# 0         0   2012040001    40001         1         1     0        1      19  \
# 1         1   2012040002    40002         1         1     0        2      25
# 2         2   2012040003    40003         1         1     1        0      13
# 3         3   2012040004    40004         2         2     0        2      13
# 4         4   2012040005    40005         2         2     0        4      19
# ...     ...          ...      ...       ...       ...   ...      ...     ...
# 1855   1855   2016040872    40872         1         1     0        1      13
# 1856   1856   2016040875    40875         1         1     0        2      17
# 1857   1857   2016040876    40876         1         1     1        1      13
# 1858   1858   2016040877    40877         2         2     0        3      13
# 1859   1859   2016040880    40880         1         1     0        1      21
#
#      county_name  CITY  ... A_POLPUR  a_polour_lit  A_POSBAC
# 0           PIMA     0  ...        2   Other Crash         1  \
# 1        YAVAPAI    90  ...        2   Other Crash         1
# 2       MARICOPA   370  ...        2   Other Crash         2
# 3       MARICOPA   190  ...        2   Other Crash         2
# 4           PIMA   530  ...        2   Other Crash         3
# ...          ...   ...  ...      ...           ...       ...
# 1855    MARICOPA     0  ...        2   Other Crash         2
# 1856      NAVAJO     0  ...        2   Other Crash         2
# 1857    MARICOPA   370  ...        2   Other Crash         3
# 1858    MARICOPA   200  ...        2   Other Crash         3
# 1859       PINAL     0  ...        2   Other Crash         1
#
#                                  a_posbac_lit  A_DIST   a_dist_lit  A_DROWSY
# 0      Driver With Positive BAC Testing Crash       2  Other Crash         2  \
# 1      Driver With Positive BAC Testing Crash       2  Other Crash         2
# 2     All Drivers With ZERO BAC Testing Crash       2  Other Crash         2
# 3     All Drivers With ZERO BAC Testing Crash       2  Other Crash         2
# 4                           Unknown BAC Crash       2  Other Crash         2
# ...                                       ...     ...          ...       ...
# 1855  All Drivers With ZERO BAC Testing Crash       2  Other Crash         2
# 1856  All Drivers With ZERO BAC Testing Crash       2  Other Crash         2
# 1857                        Unknown BAC Crash       2  Other Crash         2
# 1858                        Unknown BAC Crash       2  Other Crash         2
# 1859   Driver With Positive BAC Testing Crash       2  Other Crash         2
#
#       a_drowsy_lit INDIAN_RES    indian_res_lit
# 0      Other Crash          0  Not Tribal Lands
# 1      Other Crash          0  Not Tribal Lands
# 2      Other Crash          0  Not Tribal Lands
# 3      Other Crash          0  Not Tribal Lands
# 4      Other Crash          0  Not Tribal Lands
# ...            ...        ...               ...
# 1855   Other Crash          0  Not Tribal Lands
# 1856   Other Crash          1      Tribal Lands
# 1857   Other Crash          0  Not Tribal Lands
# 1858   Other Crash          0  Not Tribal Lands
# 1859   Other Crash          1      Tribal Lands
#
# [1860 rows x 80 columns]

# %%
accident_data.columns
# Out:
# Index(['index', 'accident_id', 'ST_CASE', 'VE_TOTAL', 'VE_FORMS', 'PEDS',
#        'PERSONS', 'COUNTY', 'county_name', 'CITY', 'city_name', 'DAY', 'MONTH',
#        'YEAR', 'HOUR', 'MINUTE', 'NHS', 'FUNC_SYS', 'func_sys_lit', 'ROAD_FNC',
#        'road_fnc_lit', 'RD_OWNER', 'rd_owner_lit', 'TWAY_ID', 'TWAY_ID2',
#        'LATITUDE', 'LONGITUDE', 'SP_JUR', 'sp_jur_lit', 'HARM_EV',
#        'harm_ev_lit', 'MAN_COLL', 'man_coll_lit', 'RELJCT1', 'RELJCT2',
#        'TYP_INT', 'WRK_ZONE', 'REL_ROAD', 'LGT_COND', 'lgt_cond_lit',
#        'WEATHER', 'weather_lit', 'SCH_BUS', 'CF1', 'CF2', 'CF3', 'cf1_lit',
#        'cf2_lit', 'cf3_lit', 'FATALS', 'A_INTER', 'a_inter_lit', 'A_ROADFC',
#        'a_road_fc_lit', 'A_TOD', 'a_tod_lit', 'A_DOW', 'a_dow_lit', 'A_LT',
#        'a_lt_lit', 'A_SPCRA', 'a_spcra_lit', 'A_PED', 'a_ped_lit', 'A_PED_F',
#        'a_ped_f_lit', 'A_PEDAL', 'a_pedal_lit', 'A_PEDAL_F', 'a_pedal_f_lit',
#        'A_POLPUR', 'a_polour_lit', 'A_POSBAC', 'a_posbac_lit', 'A_DIST',
#        'a_dist_lit', 'A_DROWSY', 'a_drowsy_lit', 'INDIAN_RES',
#        'indian_res_lit'],
#       dtype='object')

# %%
#file to load--person
person_data_to_load = Path("./Resources/person.csv")

#read accident, person, vehicle data file and store in to Pandas DataFrames
person_data = pd.read_csv(person_data_to_load)
person_data
# Out:
# C:\Users\nprab\AppData\Local\Temp\ipykernel_27716\3529465139.py:5: DtypeWarning: Columns (72,73,74,75,82,83,85,89,90,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   person_data = pd.read_csv(person_data_to_load)
#        index  accident_id  STATE  ST_CASE  VE_FORMS  VEH_NO  PER_NO  STR_VEH
# 0          0   2016040001      4    40001         1       1       1        0  \
# 1          1   2016040001      4    40001         1       1       2        0
# 2          2   2016040001      4    40001         1       1       3        0
# 3          3   2016040001      4    40001         1       1       4        0
# 4          4   2016040001      4    40001         1       1       5        0
# ...      ...          ...    ...      ...       ...     ...     ...      ...
# 10606  10606   2012040752      4    40752         1       1       2        0
# 10607  10607   2012040753      4    40753         1       1       1        0
# 10608  10608   2012040753      4    40753         1       1       2        0
# 10609  10609   2012040754      4    40754         1       0       1        1
# 10610  10610   2012040754      4    40754         1       1       1        0
#
#        COUNTY  DAY  ...  DISPLACE  MCYCL_CY  TIRE_SZE  TON_RAT  TRK_WT
# 0          21    2  ...       NaN       NaN       NaN      NaN     NaN  \
# 1          21    2  ...       NaN       NaN       NaN      NaN     NaN
# 2          21    2  ...       NaN       NaN       NaN      NaN     NaN
# 3          21    2  ...       NaN       NaN       NaN      NaN     NaN
# 4          21    2  ...       NaN       NaN       NaN      NaN     NaN
# ...       ...  ...  ...       ...       ...       ...      ...     ...
# 10606       1    2  ...       NaN       NaN       NaN      NaN     NaN
# 10607      17    7  ...       NaN       NaN       NaN      NaN     NaN
# 10608      17    7  ...       NaN       NaN       NaN      NaN     NaN
# 10609       1    8  ...       NaN       NaN       NaN      NaN     NaN
# 10610       1    8  ...       NaN       NaN       NaN      NaN     NaN
#
#        TRKWTVAR  MCYCL_WT  VIN_REST  WHLDRWHL  Year
# 0           NaN       NaN       NaN       NaN  2016
# 1           NaN       NaN       NaN       NaN  2016
# 2           NaN       NaN       NaN       NaN  2016
# 3           NaN       NaN       NaN       NaN  2016
# 4           NaN       NaN       NaN       NaN  2016
# ...         ...       ...       ...       ...   ...
# 10606       NaN       NaN       NaN       NaN  2012
# 10607       NaN       NaN       NaN       NaN  2012
# 10608       NaN       NaN       NaN       NaN  2012
# 10609       NaN       NaN       NaN       NaN  2012
# 10610       NaN       NaN       NaN       NaN  2012
#
# [10611 rows x 97 columns]

# %%
person_data.columns
# Out:
# Index(['index', 'accident_id', 'STATE', 'ST_CASE', 'VE_FORMS', 'VEH_NO',
#        'PER_NO', 'STR_VEH', 'COUNTY', 'DAY', 'MONTH', 'HOUR', 'MINUTE',
#        'RUR_URB', 'FUNC_SYS', 'HARM_EV', 'MAN_COLL', 'SCH_BUS', 'MAKE',
#        'MAK_MOD', 'BODY_TYP', 'MOD_YEAR', 'TOW_VEH', 'SPEC_USE', 'EMER_USE',
#        'ROLLOVER', 'IMPACT1', 'FIRE_EXP', 'AGE', 'SEX', 'PER_TYP', 'INJ_SEV',
#        'SEAT_POS', 'REST_USE', 'REST_MIS', 'AIR_BAG', 'EJECTION', 'EJ_PATH',
#        'EXTRICAT', 'DRINKING', 'ALC_DET', 'ALC_STATUS', 'ATST_TYP', 'ALC_RES',
#        'DRUGS', 'DRUG_DET', 'DSTATUS', 'DRUGTST1', 'DRUGTST2', 'DRUGTST3',
#        'DRUGRES1', 'DRUGRES2', 'DRUGRES3', 'HOSPITAL', 'DOA', 'DEATH_DA',
#        'DEATH_MO', 'DEATH_YR', 'DEATH_HR', 'DEATH_MN', 'DEATH_TM', 'LAG_HRS',
#        'LAG_MINS', 'P_SF1', 'P_SF2', 'P_SF3', 'WORK_INJ', 'HISPANIC', 'RACE',
#        'LOCATION', 'ROAD_FNC', 'CERT_NO', 'VINTYPE', 'VINMAKE', 'VINA_MOD',
#        'VIN_BT', 'VINMODYR', 'VIN_LNGT', 'VIN_WGT', 'WGTCD_TR', 'WHLBS_LG',
#        'WHLBS_SH', 'SER_TR', 'FUELCODE', 'MCYCL_DS', 'CARBUR', 'CYLINDER',
#        'DISPLACE', 'MCYCL_CY', 'TIRE_SZE', 'TON_RAT', 'TRK_WT', 'TRKWTVAR',
#        'MCYCL_WT', 'VIN_REST', 'WHLDRWHL', 'Year'],
#       dtype='object')

# %%
accident_data.describe()
person_data.describe()
# Out:
#               index   accident_id    STATE       ST_CASE      VE_FORMS
# count  10611.000000  1.061100e+04  10611.0  10611.000000  10611.000000  \
# mean    5305.000000  2.014098e+09      4.0  40406.093299      1.844218
# std     3063.276187  1.438967e+06      0.0    233.851713      1.270543
# min        0.000000  2.012040e+09      4.0  40001.000000      1.000000
# 25%     2652.500000  2.013040e+09      4.0  40205.000000      1.000000
# 50%     5305.000000  2.014040e+09      4.0  40407.000000      2.000000
# 75%     7957.500000  2.015041e+09      4.0  40600.000000      2.000000
# max    10610.000000  2.016041e+09      4.0  40880.000000     17.000000
#
#              VEH_NO        PER_NO       STR_VEH        COUNTY           DAY
# count  10611.000000  10611.000000  10611.000000  10611.000000  10611.000000  \
# mean       1.344171      1.721704      0.095184     15.017340     15.694939
# std        0.985717      1.442495      0.298577     29.213528      8.841795
# min        0.000000      1.000000      0.000000      1.000000      1.000000
# 25%        1.000000      1.000000      0.000000     13.000000      8.000000
# 50%        1.000000      1.000000      0.000000     13.000000     15.000000
# 75%        2.000000      2.000000      0.000000     19.000000     23.000000
# max       17.000000     20.000000      2.000000    999.000000     31.000000
#
#        ...     WHLBS_SH     MCYCL_DS     CYLINDER     DISPLACE  MCYCL_CY
# count  ...  1552.000000   149.000000  1701.000000  1551.000000     149.0  \
# mean   ...  1114.008376  1155.053691     5.691946   251.112186       4.0
# std    ...   273.023453   420.923820     1.786317   143.190373       0.0
# min    ...     0.000000   125.000000     1.000000    61.000000       4.0
# 25%    ...  1037.000000   745.000000     4.000000   146.000000       4.0
# 50%    ...  1102.000000  1304.000000     6.000000   214.000000       4.0
# 75%    ...  1200.000000  1450.000000     8.000000   325.000000       4.0
# max    ...  1680.000000  2294.000000    10.000000   915.000000       4.0
#
#             TRK_WT    TRKWTVAR     MCYCL_WT    WHLDRWHL          Year
# count   551.000000  551.000000   149.000000  551.000000  10611.000000
# mean   3588.591652    1.128857   630.449664   44.700544   2014.057676
# std    1975.724320    1.868325   213.379830    6.041913      1.438946
# min       0.000000    0.000000     0.000000   42.000000   2012.000000
# 25%    2997.000000    0.000000   432.000000   42.000000   2013.000000
# 50%    4114.000000    0.000000   660.000000   42.000000   2014.000000
# 75%    4924.000000    2.000000   776.000000   44.000000   2015.000000
# max    6723.000000   13.000000  1185.000000   64.000000   2016.000000
#
# [8 rows x 86 columns]

# %%
accident_data.dtypes
person_data.dtypes
# Out:
# index            int64
# accident_id      int64
# STATE            int64
# ST_CASE          int64
# VE_FORMS         int64
#                 ...
# TRKWTVAR       float64
# MCYCL_WT       float64
# VIN_REST        object
# WHLDRWHL       float64
# Year             int64
# Length: 97, dtype: object

# %%
# check for null values
accident_data.isnull().any()
# Out:
# index             False
# accident_id       False
# ST_CASE           False
# VE_TOTAL          False
# VE_FORMS          False
#                   ...
# a_dist_lit        False
# A_DROWSY          False
# a_drowsy_lit      False
# INDIAN_RES        False
# indian_res_lit    False
# Length: 80, dtype: bool

# %%
#checking for duplicate values--accident

accident_data.duplicated()

#removing duplicate rows

acc_data_duplicates = accident_data.drop_duplicates()
acc_data_duplicates.duplicated().sum()
# Out:
# 0

# %%
# check for null values

person_data.isnull().any()
# Out:
# index          False
# accident_id    False
# STATE          False
# ST_CASE        False
# VE_FORMS       False
#                ...
# TRKWTVAR        True
# MCYCL_WT        True
# VIN_REST        True
# WHLDRWHL        True
# Year           False
# Length: 97, dtype: bool

# %%
person_data.describe()
# Out:
#               index   accident_id    STATE       ST_CASE      VE_FORMS
# count  10611.000000  1.061100e+04  10611.0  10611.000000  10611.000000  \
# mean    5305.000000  2.014098e+09      4.0  40406.093299      1.844218
# std     3063.276187  1.438967e+06      0.0    233.851713      1.270543
# min        0.000000  2.012040e+09      4.0  40001.000000      1.000000
# 25%     2652.500000  2.013040e+09      4.0  40205.000000      1.000000
# 50%     5305.000000  2.014040e+09      4.0  40407.000000      2.000000
# 75%     7957.500000  2.015041e+09      4.0  40600.000000      2.000000
# max    10610.000000  2.016041e+09      4.0  40880.000000     17.000000
#
#              VEH_NO        PER_NO       STR_VEH        COUNTY           DAY
# count  10611.000000  10611.000000  10611.000000  10611.000000  10611.000000  \
# mean       1.344171      1.721704      0.095184     15.017340     15.694939
# std        0.985717      1.442495      0.298577     29.213528      8.841795
# min        0.000000      1.000000      0.000000      1.000000      1.000000
# 25%        1.000000      1.000000      0.000000     13.000000      8.000000
# 50%        1.000000      1.000000      0.000000     13.000000     15.000000
# 75%        2.000000      2.000000      0.000000     19.000000     23.000000
# max       17.000000     20.000000      2.000000    999.000000     31.000000
#
#        ...     WHLBS_SH     MCYCL_DS     CYLINDER     DISPLACE  MCYCL_CY
# count  ...  1552.000000   149.000000  1701.000000  1551.000000     149.0  \
# mean   ...  1114.008376  1155.053691     5.691946   251.112186       4.0
# std    ...   273.023453   420.923820     1.786317   143.190373       0.0
# min    ...     0.000000   125.000000     1.000000    61.000000       4.0
# 25%    ...  1037.000000   745.000000     4.000000   146.000000       4.0
# 50%    ...  1102.000000  1304.000000     6.000000   214.000000       4.0
# 75%    ...  1200.000000  1450.000000     8.000000   325.000000       4.0
# max    ...  1680.000000  2294.000000    10.000000   915.000000       4.0
#
#             TRK_WT    TRKWTVAR     MCYCL_WT    WHLDRWHL          Year
# count   551.000000  551.000000   149.000000  551.000000  10611.000000
# mean   3588.591652    1.128857   630.449664   44.700544   2014.057676
# std    1975.724320    1.868325   213.379830    6.041913      1.438946
# min       0.000000    0.000000     0.000000   42.000000   2012.000000
# 25%    2997.000000    0.000000   432.000000   42.000000   2013.000000
# 50%    4114.000000    0.000000   660.000000   42.000000   2014.000000
# 75%    4924.000000    2.000000   776.000000   44.000000   2015.000000
# max    6723.000000   13.000000  1185.000000   64.000000   2016.000000
#
# [8 rows x 86 columns]

# %%
#dropping missing value rows
# df = person_data.dropna(inplace=True)
# df

# %%
#to drop missing values of other cols--removes null values wherever but not entire row, so it doesnt show NAN for all
#by default its axis=0
person_data_null = person_data.dropna(axis=1)

#checking the change
person_data_null.isnull().any()
# Out:
# index          False
# accident_id    False
# STATE          False
# ST_CASE        False
# VE_FORMS       False
# VEH_NO         False
# PER_NO         False
# STR_VEH        False
# COUNTY         False
# DAY            False
# MONTH          False
# HOUR           False
# MINUTE         False
# HARM_EV        False
# MAN_COLL       False
# SCH_BUS        False
# AGE            False
# SEX            False
# PER_TYP        False
# INJ_SEV        False
# SEAT_POS       False
# REST_USE       False
# REST_MIS       False
# AIR_BAG        False
# EJECTION       False
# EJ_PATH        False
# EXTRICAT       False
# DRINKING       False
# ALC_DET        False
# ALC_STATUS     False
# ATST_TYP       False
# ALC_RES        False
# DRUGS          False
# DRUG_DET       False
# DSTATUS        False
# DRUGTST1       False
# DRUGTST2       False
# DRUGTST3       False
# DRUGRES1       False
# DRUGRES2       False
# DRUGRES3       False
# HOSPITAL       False
# DOA            False
# DEATH_DA       False
# DEATH_MO       False
# DEATH_YR       False
# DEATH_HR       False
# DEATH_MN       False
# DEATH_TM       False
# LAG_HRS        False
# LAG_MINS       False
# P_SF1          False
# P_SF2          False
# P_SF3          False
# WORK_INJ       False
# HISPANIC       False
# RACE           False
# LOCATION       False
# Year           False
# dtype: bool

# %%
person_data_null.describe()
# Out:
#               index   accident_id    STATE       ST_CASE      VE_FORMS
# count  10611.000000  1.061100e+04  10611.0  10611.000000  10611.000000  \
# mean    5305.000000  2.014098e+09      4.0  40406.093299      1.844218
# std     3063.276187  1.438967e+06      0.0    233.851713      1.270543
# min        0.000000  2.012040e+09      4.0  40001.000000      1.000000
# 25%     2652.500000  2.013040e+09      4.0  40205.000000      1.000000
# 50%     5305.000000  2.014040e+09      4.0  40407.000000      2.000000
# 75%     7957.500000  2.015041e+09      4.0  40600.000000      2.000000
# max    10610.000000  2.016041e+09      4.0  40880.000000     17.000000
#
#              VEH_NO        PER_NO       STR_VEH        COUNTY           DAY
# count  10611.000000  10611.000000  10611.000000  10611.000000  10611.000000  \
# mean       1.344171      1.721704      0.095184     15.017340     15.694939
# std        0.985717      1.442495      0.298577     29.213528      8.841795
# min        0.000000      1.000000      0.000000      1.000000      1.000000
# 25%        1.000000      1.000000      0.000000     13.000000      8.000000
# 50%        1.000000      1.000000      0.000000     13.000000     15.000000
# 75%        2.000000      2.000000      0.000000     19.000000     23.000000
# max       17.000000     20.000000      2.000000    999.000000     31.000000
#
#        ...       LAG_HRS      LAG_MINS         P_SF1         P_SF2    P_SF3
# count  ...  10611.000000  10611.000000  10611.000000  10611.000000  10611.0  \
# mean   ...    665.841674     72.587032      0.376119      0.008105      0.0
# std    ...    465.147897     38.227846      4.675683      0.834873      0.0
# min    ...      0.000000      0.000000      0.000000      0.000000      0.0
# 25%    ...      1.000000     35.000000      0.000000      0.000000      0.0
# 50%    ...    999.000000     99.000000      0.000000      0.000000      0.0
# 75%    ...    999.000000     99.000000      0.000000      0.000000      0.0
# max    ...    999.000000     99.000000     92.000000     86.000000      0.0
#
#           WORK_INJ      HISPANIC          RACE      LOCATION          Year
# count  10611.00000  10611.000000  10611.000000  10611.000000  10611.000000
# mean       4.82226      3.777966      1.934690      1.441240   2014.057676
# std        3.91583     12.753484     11.513888      8.023799      1.438946
# min        0.00000      0.000000      0.000000      0.000000   2012.000000
# 25%        0.00000      0.000000      0.000000      0.000000   2013.000000
# 50%        8.00000      0.000000      0.000000      0.000000   2014.000000
# 75%        8.00000      7.000000      1.000000      0.000000   2015.000000
# max        9.00000     99.000000     99.000000     99.000000   2016.000000
#
# [8 rows x 59 columns]

# %%
#checking for duplicate values--person

person_data_null.duplicated()

#removing duplicate rows

person_duplicates = person_data_null.drop_duplicates()

#checking for specific duplicate rows after removal

person_duplicates.duplicated().sum()
# Out:
# 0

# %%
person_duplicates.columns
# Out:
# Index(['index', 'accident_id', 'STATE', 'ST_CASE', 'VE_FORMS', 'VEH_NO',
#        'PER_NO', 'STR_VEH', 'COUNTY', 'DAY', 'MONTH', 'HOUR', 'MINUTE',
#        'HARM_EV', 'MAN_COLL', 'SCH_BUS', 'AGE', 'SEX', 'PER_TYP', 'INJ_SEV',
#        'SEAT_POS', 'REST_USE', 'REST_MIS', 'AIR_BAG', 'EJECTION', 'EJ_PATH',
#        'EXTRICAT', 'DRINKING', 'ALC_DET', 'ALC_STATUS', 'ATST_TYP', 'ALC_RES',
#        'DRUGS', 'DRUG_DET', 'DSTATUS', 'DRUGTST1', 'DRUGTST2', 'DRUGTST3',
#        'DRUGRES1', 'DRUGRES2', 'DRUGRES3', 'HOSPITAL', 'DOA', 'DEATH_DA',
#        'DEATH_MO', 'DEATH_YR', 'DEATH_HR', 'DEATH_MN', 'DEATH_TM', 'LAG_HRS',
#        'LAG_MINS', 'P_SF1', 'P_SF2', 'P_SF3', 'WORK_INJ', 'HISPANIC', 'RACE',
#        'LOCATION', 'Year'],
#       dtype='object')

# %%
#dropping other columns, selecting the necessary col

Dataframe_age = person_duplicates[['AGE','accident_id']]
Dataframe_age
# Out:
#        AGE  accident_id
# 0       33   2016040001
# 1       26   2016040001
# 2       36   2016040001
# 3       10   2016040001
# 4       23   2016040001
# ...    ...          ...
# 10606   42   2012040752
# 10607  999   2012040753
# 10608   34   2012040753
# 10609   32   2012040754
# 10610  999   2012040754
#
# [10611 rows x 2 columns]

# %%
# Filter the data based on age less than 90
filtered_data = Dataframe_age[Dataframe_age['AGE'] < 90]
filtered_data
# Out:
#        AGE  accident_id
# 0       33   2016040001
# 1       26   2016040001
# 2       36   2016040001
# 3       10   2016040001
# 4       23   2016040001
# ...    ...          ...
# 10602   24   2012040751
# 10604   38   2012040751
# 10606   42   2012040752
# 10608   34   2012040753
# 10609   32   2012040754
#
# [10129 rows x 2 columns]

# %%
# Group by 'AGE' and count the number of occurrences

age_counts = filtered_data['AGE'].value_counts()
age_counts
# Out:
# AGE
# 21    269
# 18    265
# 22    265
# 23    253
# 24    242
#      ...
# 84     26
# 85     24
# 89     21
# 87     18
# 88     15
# Name: count, Length: 90, dtype: int64

# %%
# #filter out the 'AGE' values that have more than one occurrence.
# Filter 'AGE' with more values
age_counts_filtered = age_counts[age_counts >1]

# Create a DataFrame with the filtered 'AGE' counts
filtered_df = age_counts_filtered.reset_index()
filtered_df.columns = ['AGE', 'Count']

# Plot the data using a bar chart
plt.figure(figsize=(10, 6))
plt.bar(filtered_df['AGE'], filtered_df['Count'])
plt.xlabel('age')
plt.ylabel('accidents')
plt.title('Frequency of accidents with age < 90')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.)
plt.savefig("output_data/Fig1.png")
plt.show()


# # Filter the DataFrame for ages less than 90
# filtered_data = Dataframe_age[Dataframe_age['AGE'] < 90]

# # Plot a histogram to show the frequency of accidents for ages less than 90
# #bins=10: This parameter sets the number of bins to 10, meaning the ages will be divided into 10 intervals on the x-axis for the histogram.
# plt.hist(filtered_data['AGE'], bins=10, color='skyblue', edgecolor='black')
# plt.xlabel('Age')
# plt.ylabel('Frequency')
# plt.title('Frequency of Accidents for Ages < 90')
# plt.show()

# %%
#dropping other columns, selecting the necessary col--acc

Dataframe_weather_tway = acc_data_duplicates[['weather_lit','TWAY_ID','lgt_cond_lit','YEAR']]
Dataframe_weather_tway
# Out:
#        weather_lit                     TWAY_ID             lgt_cond_lit  YEAR
# 0            Clear                   CLAUDE ST       Dark - Not Lighted  2012
# 1           Cloudy                      SR-89A                 Daylight  2012
# 2            Clear                    69TH AVE           Dark - Lighted  2012
# 3            Clear                   ELLIOT RD           Dark - Lighted  2012
# 4            Clear                       SR-83       Dark - Not Lighted  2012
# ...            ...                         ...                      ...   ...
# 1855  Not Reported                 WOODSIDE DR                  Unknown  2016
# 1856  Not Reported                  UNKNOWN RD                  Unknown  2016
# 1857  Not Reported              UNION HILLS DR  Dark - Unknown Lighting  2016
# 1858         Clear              UNION HILLS DR                 Daylight  2016
# 1859         Clear  INDIAN ROUTE 121- ASPEN RD                     Dusk  2016
#
# [1860 rows x 4 columns]

# %%
# 'acc_data_duplicates' contains data:
#Dataframe_weather_tway = acc_data_duplicates[['weather_lit','TWAY_ID','lgt_cond_lit','YEAR']]
quartile_summary = acc_data_duplicates['LATITUDE']
quartile_summary
quartile_summary = acc_data_duplicates['LATITUDE'].describe(percentiles=[0.25, 0.75])

# Extract the lower and upper quartiles from the summary
lower_bound = quartile_summary['25%']
upper_bound = quartile_summary['75%']

acc_data_cleaned = acc_data_duplicates[(acc_data_duplicates['LATITUDE'] >= lower_bound) & 
                    (acc_data_duplicates['LATITUDE'] <= upper_bound)]
acc_data_cleaned
Dataframe_weather_tway = acc_data_cleaned[['LATITUDE','accident_id']]

# Group by latitude and aggregate the accident counts--group the data lat col
#Use an aggregate function 'count' to summarize the accident data within each latitude group.

accidents_by_latitude = Dataframe_weather_tway.groupby('LATITUDE').agg({'accident_id': 'count'}).reset_index()

#Plot the aggregated data to view the relationship between accidents and latitude.
accidents_by_latitude.plot(x='LATITUDE',
                           y='accident_id', 
                           kind='scatter', 
                           xlabel='Latitude', 
                           ylabel='Number of Accidents', title='Accidents by Latitude')
plt.savefig("output_data/Fig2.png")


# plt.figure(figsize=(10, 6))
# plt.scatter(accidents_by_latitude['LATITUDE'], accidents_by_latitude['accident_id'], color='skyblue', alpha=0.7)
# plt.xlabel('Latitude')
# plt.ylabel('Number of Accidents')
# plt.title('Accidents by Latitude')
# plt.grid(True)
# plt.show()

# %%
tway_counts = acc_data_duplicates['TWAY_ID'].value_counts()
tway_counts
# Out:
# TWAY_ID
# US-191                        48
# UNKNOWN RD                    36
# SR-87                         33
# MCDOWELL RD                   33
# SR-264                        29
#                               ..
# CAMINO DE OESTE                1
# OUTER LOOP RD                  1
# COUNTY 15TH ST                 1
# LENZER AVE                     1
# INDIAN ROUTE 121- ASPEN RD     1
# Name: count, Length: 881, dtype: int64

# %%
#filter out the 'TWAY_ID' values that have more than one occurrence.
# Filter 'TWAY_ID' with more values
tway_counts_filtered = tway_counts[tway_counts >9]
tway_counts_filtered
# Create a DataFrame with the filtered 'TWAY_ID' counts
filtered_df = tway_counts_filtered.reset_index()
filtered_df.columns = ['TWAY_ID', 'Count']
filtered_df.columns
# Plot the data using a bar chart
plt.figure(figsize=(12, 4))
bars= plt.bar(filtered_df['TWAY_ID'], filtered_df['Count'])
plt.xlabel('TWAY_ID')
plt.ylabel('Accidents')
plt.title('Number of Accidents with TWAY_ID')
plt.xticks(rotation=85)
plt.grid(axis='y', linestyle='--', alpha=0.2)
plt.bar_label(bars, labels=filtered_df['Count'], label_type='edge')

plt.savefig("output_data/Fig3.png",bbox_inches='tight')
plt.show()

# %%
#pie chat showing distribution of weather

count = acc_data_duplicates['YEAR'].value_counts()
plt.pie(count.values, labels = count.index, autopct = '%1.1f%%')
plt.title('distribution of accidents')
plt.savefig("output_data/Fig4.png")
plt.show()

# %%
#filter the col year and weather_lit

filtered_df= acc_data_duplicates[['YEAR','weather_lit']]
filtered_df

#group the data by year and weather_lit to get counts
grouped_data = filtered_df.groupby(['YEAR', 'weather_lit']).size()

grouped_data.plot(kind='bar', figsize=(12, 4))
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Distribution of accidents over the Years in different weather')
plt.savefig("output_data/Fig4.png",bbox_inches='tight')
plt.show()

# %%
# # Group data by 'lgt_cond_lit' and 'YEAR' to count the number of accidents per traffic way per year
# accidents_by_tway_year = acc_data_duplicates.groupby(['lgt_cond_lit', 'YEAR']).size().reset_index(name='accident_count')

# # Create a pivot table to reshape the data for plotting
# pivot_table = accidents_by_tway_year.pivot(index='YEAR', columns='lgt_cond_lit', values='accident_count')

# # Plot a stacked bar chart showing the number of accidents in different traffic ways over the years
# pivot_table.plot(kind='bar', figsize=(12, 6))  

# # Set labels and title for the chart
# plt.xlabel('Year')
# plt.ylabel('Number of Accidents')
# plt.title('Number of Accidents in Different conditions Over the Years')
# plt.legend(title='conditions', loc='upper right')
# plt.savefig("output_data/Fig5.png")
# # Display the chart
# plt.show()



filtered_df= acc_data_duplicates[['lgt_cond_lit','YEAR']]
filtered_df


# Group the data by "YEAR" and "lgt_cond_lit" and count the number of accidents
grouped_data = filtered_df.groupby(['YEAR', 'lgt_cond_lit']).size()

# Plot a bar chart
grouped_data.unstack().plot(kind='bar', stacked=True, figsize=(12, 4))
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.title('Number of Accidents in Different Light Conditions by Year')
#plt.legend(title='Light Condition')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.savefig("output_data/Fig5.png",bbox_inches='tight')
plt.show()
